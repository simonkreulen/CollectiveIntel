# %% [markdown]
# # Groeps Opdracht CI
# ## Joost Vledder, Sadjia Safdari, Simon Kreulen & Jasper van Eck

# %% [markdown]
# ### Inhoudsopgave <a name='Top'></a>
#
# [Imports](#import)
#
# [Load data](#loaddata)
#
# [Data Clean Up](#cleanup)
#
# [Basic Data Stats](#basicdata)
#
# [Plots](#plots)

# %% [markdown]
# ### Imports <a name='import'></a>
#
# [Top](#Top)

# %%
import os
import pandas as pd
import numpy as np
np.seterr(divide='raise', over='raise', under='raise', invalid='raise')
import matplotlib.pyplot as plt
from collections import defaultdict

# %% [markdown]
# ### Load data <a name='loaddata'></a>
#
# [Top](#Top)

# %%
#rootdir = './yelp/data'
rootdir = './yelp/data'

df_business = pd.DataFrame()
df_users = pd.DataFrame()
df_reviews = pd.DataFrame()

count = 0

for subdir, dirs, files in os.walk(rootdir):
    if count == 200: #1078 is the total amount of cities
        break
        
    for file in files:
        if os.path.basename(file) == 'business.json':
            df_business = df_business.append(pd.read_json(os.path.join(subdir, file),lines=True))
        if os.path.basename(file) == 'user.json':
            df_users = df_users.append(pd.read_json(os.path.join(subdir, file),lines=True))
        if os.path.basename(file) == 'review.json':
            df_reviews = df_reviews.append(pd.read_json(os.path.join(subdir, file),lines=True))
    count += 1

df_business = df_business.set_index('business_id')
df_users = df_users.set_index('user_id')
df_reviews = df_reviews.set_index('review_id')

display(df_business.head())
display(df_users.head())
display(df_reviews.head())
# Out:
#                                                                      name  \
# business_id
# t8xvlKk5axVYy2c2p70NRg                         Makeup By Kassandra Franco
# 6E5SM3-YvBpdzNNW68ksTw  Yvette Tavitian -  Allison James Estate & Home...
# d4GBb0eVWVdfL5aJx3UCRg                                       Casual Water
# XZ6cTNYjdO0MzqLqT9EMyw                              Tega Cay Gourmet Deli
# UM07j7HtW-dhr8Gq3LQLxg                                    521 BBQ & Grill
#
#                                                      address          city  \
# business_id
# t8xvlKk5axVYy2c2p70NRg                                        Las Vegas Nv
# 6E5SM3-YvBpdzNNW68ksTw           4431 S Eastern Ave, Ste 250  Las Vegas NV
# d4GBb0eVWVdfL5aJx3UCRg  Tega Cay Golf Club, 15083 Molokai Dr      Tega Cay
# XZ6cTNYjdO0MzqLqT9EMyw                  1143 Stonecrest Blvd      Tega Cay
# UM07j7HtW-dhr8Gq3LQLxg         1135 Stonecrest Blvd, Ste 101      Tega Cay
#
#                        state postal_code   latitude   longitude  stars  \
# business_id
# t8xvlKk5axVYy2c2p70NRg    CA       92703  36.169941 -115.139830    4.5
# 6E5SM3-YvBpdzNNW68ksTw    NV       89074  36.028157 -115.088426    4.5
# d4GBb0eVWVdfL5aJx3UCRg    SC       29708  35.024312  -81.027855    3.5
# XZ6cTNYjdO0MzqLqT9EMyw    SC       29708  35.047500  -80.991899    4.5
# UM07j7HtW-dhr8Gq3LQLxg    SC       29708  35.047959  -80.992330    4.0
#
#                         review_count  is_open  \
# business_id
# t8xvlKk5axVYy2c2p70NRg            15        1
# hWy2VgPZ3q5HRF2XiNq7BQ  I absolutely  love her work. Best makeup artis...
# shNm4bvg0EUSnKlZRdVpDg  Yvette was an AMAZING agent. I had previously ...
# N7qCKRDgC4YwVprWZsEfoQ  I would definitely recommend Kassandra to all ...
# UCt2RgQSZcp7RhDZOPkTRA  The makeup and contouring class I attended was...
#
#                                       date
# review_id
# JKNGyHyf9i5_yk8_BgYIow 2018-02-11 02:47:56
# hWy2VgPZ3q5HRF2XiNq7BQ 2016-01-31 00:26:47
# shNm4bvg0EUSnKlZRdVpDg 2018-09-05 06:45:46
# N7qCKRDgC4YwVprWZsEfoQ 2016-07-06 17:05:23
# UCt2RgQSZcp7RhDZOPkTRA 2014-03-02 22:04:44

# %%
df_business.to_pickle('./business_pickle.pkl')
df_users.to_pickle('./users_pickle.pkl')
df_reviews.to_pickle('./reviews_pickle.pkl')

# %%
df_business = pd.read_pickle('./business_pickle.pkl')
df_users = pd.read_pickle('./users_pickle.pkl')
df_reviews = pd.read_pickle('./reviews_pickle.pkl')

# %% [markdown]
# ### Clean up Data For Content Based <a name='cleanup'></a>
#
# [Top](#Top)

# %%
cat_dict = defaultdict(lambda: defaultdict(int))

# Drop na categories
df_business = df_business[df_business['categories'].notna()]

# Normalize long, lat, stars & review_count
#x = cos(lat) * cos(lon)
#y = cos(lat) * sin(lon)
df_business['stars'] = (df_business['stars']-df_business['stars'].min()) / (df_business['stars'].max()-df_business['stars'].min())
df_business['review_count'] = (df_business['review_count']-df_business['review_count'].min()) / (df_business['review_count'].max()-df_business['review_count'].min())
df_business['x_axis'] = np.cos(df_business['latitude']) * np.cos(df_business['longitude'])
df_business['y_axis'] = np.cos(df_business['latitude']) * np.sin(df_business['longitude'])

# Dataframe of categories one hot encoded per business_id
df_tmp = df_business['categories'].str.split(pat=', ',expand=True)

# Create dict of categories
for index, row in df_tmp.iterrows():
    for _,elem in row.items():
        if elem and elem not in cat_dict[index]:
            cat_dict[index][elem] += 1

# %%
# Create DF from dict
df_cats = pd.DataFrame.from_dict(cat_dict, orient='index')

#Drop NaN column
df_cats = df_cats.drop(columns='NaN',errors='ignore')

# Fillna with 0
df_cats = df_cats.fillna(0)

# Join back into business
df_business = df_business.join(df_cats,on='business_id')

# Drop cols
df_business = df_business.drop(columns=['address','city','state','postal_code','latitude','longitude','attributes','categories','hours'],errors='ignore')

# Remove elite & friends columns because of non use
df_users = df_users.drop(columns=['elite','friends'],axis=1,errors='ignore')

# %%
display(df_business.head())
# Out:
#                                                                      name  \
# business_id
# t8xvlKk5axVYy2c2p70NRg                         Makeup By Kassandra Franco
# 6E5SM3-YvBpdzNNW68ksTw  Yvette Tavitian -  Allison James Estate & Home...
# d4GBb0eVWVdfL5aJx3UCRg                                       Casual Water
# XZ6cTNYjdO0MzqLqT9EMyw                              Tega Cay Gourmet Deli
# UM07j7HtW-dhr8Gq3LQLxg                                    521 BBQ & Grill
#
#                         stars  review_count  is_open    x_axis    y_axis  \
# business_id
# t8xvlKk5axVYy2c2p70NRg  0.875      0.005362        1 -0.018909 -0.037069
# 6E5SM3-YvBpdzNNW68ksTw  0.875      0.000000        1  0.040799  0.091288
# d4GBb0eVWVdfL5aJx3UCRg  0.625      0.008937        0 -0.708990 -0.542965
# XZ6cTNYjdO0MzqLqT9EMyw  0.875      0.041108        1 -0.680778 -0.561310
# UM07j7HtW-dhr8Gq3LQLxg  0.750      0.046917        1 -0.680853 -0.560879
#
#                         Hair Extensions  Hair Stylists  Makeup Artists  \
# business_id
# t8xvlKk5axVYy2c2p70NRg              1.0            1.0             1.0
# 6E5SM3-YvBpdzNNW68ksTw              0.0            0.0             0.0
# d4GBb0eVWVdfL5aJx3UCRg              0.0            0.0             0.0
# XZ6cTNYjdO0MzqLqT9EMyw              0.0            0.0             0.0
# UM07j7HtW-dhr8Gq3LQLxg              0.0            0.0             0.0
#
#                         Hair Salons  ...  Taxidermy  Pedicabs  Shaved Snow  \
# business_id                          ...
# t8xvlKk5axVYy2c2p70NRg          1.0  ...        0.0       0.0          0.0
# 6E5SM3-YvBpdzNNW68ksTw          0.0  ...        0.0       0.0          0.0
# d4GBb0eVWVdfL5aJx3UCRg          0.0  ...        0.0       0.0          0.0
# XZ6cTNYjdO0MzqLqT9EMyw          0.0  ...        0.0       0.0          0.0
# UM07j7HtW-dhr8Gq3LQLxg          0.0  ...        0.0       0.0          0.0
#
#                         Duty-Free Shops  Race Tracks  Digitizing Services  \
# business_id
# t8xvlKk5axVYy2c2p70NRg              0.0          0.0                  0.0
# 6E5SM3-YvBpdzNNW68ksTw              0.0          0.0                  0.0
# d4GBb0eVWVdfL5aJx3UCRg              0.0          0.0                  0.0
# XZ6cTNYjdO0MzqLqT9EMyw              0.0          0.0                  0.0
# UM07j7HtW-dhr8Gq3LQLxg              0.0          0.0                  0.0
#
#                         Duplication Services  Hepatologists  Horse Racing  \
# business_id
# t8xvlKk5axVYy2c2p70NRg                   0.0            0.0           0.0
# 6E5SM3-YvBpdzNNW68ksTw                   0.0            0.0           0.0
# d4GBb0eVWVdfL5aJx3UCRg                   0.0            0.0           0.0
# XZ6cTNYjdO0MzqLqT9EMyw                   0.0            0.0           0.0
# UM07j7HtW-dhr8Gq3LQLxg                   0.0            0.0           0.0
#
#                         Ski Schools
# business_id
# t8xvlKk5axVYy2c2p70NRg          0.0
# 6E5SM3-YvBpdzNNW68ksTw          0.0
# d4GBb0eVWVdfL5aJx3UCRg          0.0
# XZ6cTNYjdO0MzqLqT9EMyw          0.0
# UM07j7HtW-dhr8Gq3LQLxg          0.0
#
# [5 rows x 1178 columns]

# %%
df_business.to_pickle('./business_pickle.pkl')
df_users.to_pickle('./users_pickle.pkl')
df_reviews.to_pickle('./reviews_pickle.pkl')

# %%
df_business = pd.read_pickle('./business_pickle.pkl')
df_users = pd.read_pickle('./users_pickle.pkl')
df_reviews = pd.read_pickle('./reviews_pickle.pkl')

# %% [markdown]
# ### Basic Data Stats for Content Based<a name='basicdata'></a>
#
# [Top](#Top)

# %%
# Some information about the category amounts per business

# series of amount of categories per business
cats_business = df_cats.sum(axis=1)
display(cats_business)

avg_cats_bus = cats_business.mean()
max_cats_bus = cats_business.max()
min_cats_bus = cats_business.min()

print('Average amount of categories for businesses: ', avg_cats_bus)
print('Minimum amount of categories for businesses: ', min_cats_bus)
print('Maximum amount of categories for businesses: ', max_cats_bus)

# series of amount of businesses with the index amount of categories
cat_bus_distribution = cats_business.value_counts()
display(cat_bus_distribution)
# Out:
# t8xvlKk5axVYy2c2p70NRg    5.0
# gl0yQ1sjbrTFNKqL86nvgQ    6.0
# yIMp0Jfbf-QxhFIFrLX5hw    6.0
# 7JTTMgEOdE3gnv4zLUS40A    6.0
# Fv1lLqfYbDkpbO7xGKSugg    4.0
#                          ...
# qleEk6ZaH6iolBZmltkHSg    2.0
# irDcFvUhm6RzDZoseUoLCg    2.0
# 0Nif1dcSQPDTipU-FEKC8g    2.0
# ArE3m3mTQ9rkP8NnQaG3HQ    2.0
# jutfk7U4GV899q6qfYp5dA    2.0
# Length: 34594, dtype: float64
# Average amount of categories for businesses:  4.112620685668035
# Minimum amount of categories for businesses:  1.0
# Maximum amount of categories for businesses:  21.0
# 2.0     8761
# 3.0     7006
# 4.0     6370
# 5.0     4883
# 6.0     3102
# 7.0     1962
# 8.0     1026
# 9.0      630
# 10.0     312
# 1.0      189
# 11.0     177
# 12.0      77
# 13.0      37
# 14.0      24
# 15.0      15
# 16.0      11
# 17.0       6
# 18.0       4
# 21.0       1
# 20.0       1
# dtype: int64

# %%
# series of number of businesses with index as category
cats_presences = df_cats.sum(axis=0).sort_values(ascending=False)
display(cats_presences)

avg_cats = cats_presences.mean()
max_cats = cats_presences.max()
min_cats = cats_presences.min()
# Out:
# Restaurants         9388.0
# Shopping            5852.0
# Food                4947.0
# Home Services       4332.0
# Health & Medical    3662.0
#                      ...
# Public Adjusters       1.0
# Surfing                1.0
# Shoe Shine             1.0
# Civic Center           1.0
# Ski Schools            1.0
# Length: 1172, dtype: float64

# %% [markdown]
# ### Plots <a name='plots'></a>
#
# [Top](#Top)

# %%
hist_bus = df_business.hist(column=['stars','review_count'])
df_business.plot(x='x_axis',y='y_axis',kind='scatter')
plt.show()
cats_presences.plot()

# %% [markdown]
# ### Basic Data Stats for Collaborative Based <a name='basicdata'></a>
#
# [Top](#Top)

# %%
# reset index
df_reviews = df_reviews.reset_index()

# count reviews per user and reviews per business
reviews_per_user = df_reviews.groupby("user_id")["review_id"].count().sort_values(ascending=False).to_frame()
reviews_per_business = df_reviews.groupby("business_id")["review_id"].count().sort_values(ascending=False).to_frame()


# plot both review counts
reviews_per_user.plot()
reviews_per_business.plot()
