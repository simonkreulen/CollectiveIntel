# %% [markdown]
# # Groeps Opdracht CI
# ## Joost Vledder, Sadjia Safdari, Simon Kreulen & Jasper van Eck

# %% [markdown]
# ### Imports

# %%
import os
import pandas as pd
import numpy as np
np.seterr(divide='raise', over='raise', under='raise', invalid='raise')
import matplotlib.pyplot as plt
from collections import defaultdict

# %% [markdown]
# ### Load data

# %%
#rootdir = './yelp/data'
rootdir = './yelp/yelp/data'

df_business = pd.DataFrame()
df_users = pd.DataFrame()
df_reviews = pd.DataFrame()

count = 0

for subdir, dirs, files in os.walk(rootdir):
    if count == 200: #1078 is the total amount of cities
        break
        
    for file in files:
        if os.path.basename(file) == 'business.json':
            df_business = df_business.append(pd.read_json(os.path.join(subdir, file),lines=True))
        if os.path.basename(file) == 'user.json':
            df_users = df_users.append(pd.read_json(os.path.join(subdir, file),lines=True))
        if os.path.basename(file) == 'review.json':
            df_reviews = df_reviews.append(pd.read_json(os.path.join(subdir, file),lines=True))
    count += 1

df_business = df_business.set_index('business_id')
df_users = df_users.set_index('user_id')
df_reviews = df_reviews.set_index('review_id')

display(df_business.head())
display(df_users.head())
display(df_reviews.head())
# Out:
#                                           name                        address  \
# business_id
# M82c96ICluambjx0wWg6Bg           ABZ Auto Care  9827 W Tropicana Ave, Ste 100
# U_ihDw5JhfmSKBUUkpEQqw              McDonald's         3850 Sheppard Avenue E
# LixFCMGKdptI8WRsjAl5cQ              McDonald's            2936 Finch Avenue E
# 064fFc4CdNxAJJDVR-7FSQ  Horton Carpet Cleaning
# UY1BHeeb1oE0-uk0EKqaGg              McDonald's                10823 S 51st St
#
#                                  city state postal_code   latitude  \
# business_id
# M82c96ICluambjx0wWg6Bg  110 Las Vegas    NV       89147  36.099575
# U_ihDw5JhfmSKBUUkpEQqw      Agincourt    ON     M1T 3L4  43.784517
# LixFCMGKdptI8WRsjAl5cQ      AGINCOURT    ON     M1W 2T4  43.794305
# 064fFc4CdNxAJJDVR-7FSQ     Ahwahtukee    AZ       85044  33.321112
# UY1BHeeb1oE0-uk0EKqaGg      Ahwatukee    AZ       85044  33.348551
#
#                          longitude  stars  review_count  is_open  \
# business_id
# M82c96ICluambjx0wWg6Bg -115.306722    5.0            68        0
# U_ihDw5JhfmSKBUUkpEQqw  -79.291325    2.5             5        1
# LixFCMGKdptI8WRsjAl5cQ  -79.329995    2.0             7        1
# 064fFc4CdNxAJJDVR-7FSQ -111.988020    5.0            17        1
# UY1BHeeb1oE0-uk0EKqaGg -111.975151    1.5             7        0
#
#                                                                attributes  \
# business_id
# M82c96ICluambjx0wWg6Bg             {'BusinessAcceptsCreditCards': 'True'}
# U_ihDw5JhfmSKBUUkpEQqw  {'GoodForMeal': '{'dessert': False, 'latenight...
# LixFCMGKdptI8WRsjAl5cQ  {'HasTV': 'True', 'RestaurantsGoodForGroups': ...
# 064fFc4CdNxAJJDVR-7FSQ             {'BusinessAcceptsCreditCards': 'True'}
# UY1BHeeb1oE0-uk0EKqaGg  {'Alcohol': 'u'none'', 'RestaurantsReservation...
#
#                                                                categories  \
# business_id
# M82c96ICluambjx0wWg6Bg  Automotive, Auto Repair, Oil Change Stations, ...
# U_ihDw5JhfmSKBUUkpEQqw                    Burgers, Restaurants, Fast Food
# LixFCMGKdptI8WRsjAl5cQ                    Fast Food, Restaurants, Burgers
# 064fFc4CdNxAJJDVR-7FSQ  Home Cleaning, Professional Services, Home Ser...
# UY1BHeeb1oE0-uk0EKqaGg              Food, Burgers, Fast Food, Restaurants
#
#                                                                     hours
# business_id
# M82c96ICluambjx0wWg6Bg  {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...
# U_ihDw5JhfmSKBUUkpEQqw  {'Monday': '7:0-11:0', 'Tuesday': '7:0-11:0', ...
# LixFCMGKdptI8WRsjAl5cQ  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 064fFc4CdNxAJJDVR-7FSQ  {'Monday': '8:0-19:0', 'Tuesday': '8:0-19:0', ...
# UY1BHeeb1oE0-uk0EKqaGg                                               None
#                          name  review_count        yelping_since  useful  \
# user_id
# cFGAElozHTdQDfHimOiSBQ  Alexa           164  2008-09-05 07:13:34     715
# RZ1Fq9AuQ0OkRdTzpr1NvA  Helen             9  2010-05-10 19:08:38      35
# 7uWE7YWlRrde5fifL9KTuQ   Eric            24  2012-08-16 01:50:23     149
# IdGt5n3oUA6-SBRfTPCLJg    Kim            46  2013-01-27 21:44:58      78
# AMdGLT8LlCeHcTFISfXQMA  Annie            27  2016-03-10 00:25:16      47
#
#                         funny  cool           elite  \
# user_id
# cFGAElozHTdQDfHimOiSBQ    318   394  2015,2016,2017
# RZ1Fq9AuQ0OkRdTzpr1NvA     32    35
# 7uWE7YWlRrde5fifL9KTuQ     57   125
# IdGt5n3oUA6-SBRfTPCLJg     46    58
# AMdGLT8LlCeHcTFISfXQMA     35    43
#
#                                                                   friends  \
# user_id
# cFGAElozHTdQDfHimOiSBQ  db8n21wt96O2XmLn1WSidg, drVEocTGKbGRO9-b8Dve0g...
# RZ1Fq9AuQ0OkRdTzpr1NvA  dS2nxBC_PSHtPh2ZVNkvmQ, Gzw5r_LGZ_rOofc3u9gsSg...
# 7uWE7YWlRrde5fifL9KTuQ  gBzcQ-FFvEVUdIxdUdf3EQ, sqJZt_Z144RWGk4bdKTpSw...
# IdGt5n3oUA6-SBRfTPCLJg  qmhD1iTfB5tx_tGjWTFOxw, R2w6YYFLndu0WXRq6pljqg...
# AMdGLT8LlCeHcTFISfXQMA  kebM1adVv3Tb4DB3C1TboA, BVVCNsLbNCzoDg2ByDFeyA...
#
#                         fans  average_stars  ...  compliment_more  \
# user_id                                      ...
# cFGAElozHTdQDfHimOiSBQ    25           3.29  ...                2
# RZ1Fq9AuQ0OkRdTzpr1NvA     2           4.22  ...                0
# 7uWE7YWlRrde5fifL9KTuQ     0           4.46  ...                0
# IdGt5n3oUA6-SBRfTPCLJg     0           4.37  ...                1
# AMdGLT8LlCeHcTFISfXQMA     0           4.48  ...                0
#
#                         compliment_profile  compliment_cute  compliment_list  \
# user_id
# cFGAElozHTdQDfHimOiSBQ                   0                1                0
# RZ1Fq9AuQ0OkRdTzpr1NvA                   0                0                0
# 7uWE7YWlRrde5fifL9KTuQ                   1                0                0
# IdGt5n3oUA6-SBRfTPCLJg                   0                0                0
# AMdGLT8LlCeHcTFISfXQMA                   0                0                0
#
#                         compliment_note  compliment_plain  compliment_cool  \
# user_id
# cFGAElozHTdQDfHimOiSBQ                6                 4               22
# RZ1Fq9AuQ0OkRdTzpr1NvA                0                 0                0
# 7uWE7YWlRrde5fifL9KTuQ                0                 0                0
# IdGt5n3oUA6-SBRfTPCLJg                1                 2                0
# AMdGLT8LlCeHcTFISfXQMA                0                 0                0
#
#                         compliment_funny  compliment_writer  compliment_photos
# user_id
# cFGAElozHTdQDfHimOiSBQ                22                  2                  4
# RZ1Fq9AuQ0OkRdTzpr1NvA                 0                  0                  0
# 7uWE7YWlRrde5fifL9KTuQ                 0                  1                  0
# IdGt5n3oUA6-SBRfTPCLJg                 0                  0                  0
# AMdGLT8LlCeHcTFISfXQMA                 0                  0                  0
#
# [5 rows x 21 columns]
#                                        user_id             business_id  stars  \
# review_id
# U2DCXuY8cnqEXKiDM2StVg  arH9TJhwjaSh8qVnJ7nmTQ  M82c96ICluambjx0wWg6Bg      5
# PlsccX4ZGkWNbImY_UBkbw  fZmlBl4hVOm-A7xFJ14vAA  M82c96ICluambjx0wWg6Bg      5
# UuyZlQu9Cn44BM7EEiHkjg  9oPadfz_B_uzCKMRZq2CHg  M82c96ICluambjx0wWg6Bg      5
# 0URo0Dp6t1cQiBTMCwqUgQ  sLCVE32lUjPit-kUvlZg2w  M82c96ICluambjx0wWg6Bg      5
# ITG1-seS_pi32XEJxfff3Q  a2cPSPOgHSSsrMtqYBjk0w  M82c96ICluambjx0wWg6Bg      5
#
#                         useful  funny  cool  \
# review_id
# U2DCXuY8cnqEXKiDM2StVg      70     35    70
# PlsccX4ZGkWNbImY_UBkbw      68     34    67
# UuyZlQu9Cn44BM7EEiHkjg      30     29    30
# 0URo0Dp6t1cQiBTMCwqUgQ      83     31    81
# ITG1-seS_pi32XEJxfff3Q      41     39    41
#
#                                                                      text  \
# review_id
# U2DCXuY8cnqEXKiDM2StVg  Best place to take your Car , no BS  and hones...
# PlsccX4ZGkWNbImY_UBkbw  I just moved here to Las Vegas and was looking...
# UuyZlQu9Cn44BM7EEiHkjg  Shlomi is one of the best mechanics in Las Veg...
# 0URo0Dp6t1cQiBTMCwqUgQ  I called first to find out rates. Shlomi took ...
# ITG1-seS_pi32XEJxfff3Q  Went in for a smog check.  No waiting, did the...
#
#                                       date
# review_id
# U2DCXuY8cnqEXKiDM2StVg 2015-11-18 20:01:15
# PlsccX4ZGkWNbImY_UBkbw 2016-07-14 21:50:48
# UuyZlQu9Cn44BM7EEiHkjg 2017-07-28 21:53:34
# 0URo0Dp6t1cQiBTMCwqUgQ 2016-03-31 22:27:59
# ITG1-seS_pi32XEJxfff3Q 2017-08-08 19:10:43

# %%
df_business.to_pickle('./business_pickle.pkl')
df_users.to_pickle('./users_pickle.pkl')
df_reviews.to_pickle('./reviews_pickle.pkl')

# %%
df_business = pd.read_pickle('./business_pickle.pkl')
df_users = pd.read_pickle('./users_pickle.pkl')
df_reviews = pd.read_pickle('./reviews_pickle.pkl')

# %% [markdown]
# ### Clean up Data For Content Based

# %%
cat_dict = defaultdict(lambda: defaultdict(int))

# Drop na categories
df_business = df_business[df_business['categories'].notna()]

# Normalize long, lat, stars & review_count
#x = cos(lat) * cos(lon)
#y = cos(lat) * sin(lon)
df_business['stars'] = (df_business['stars']-df_business['stars'].min()) / (df_business['stars'].max()-df_business['stars'].min())
df_business['review_count'] = (df_business['review_count']-df_business['review_count'].min()) / (df_business['review_count'].max()-df_business['review_count'].min())
df_business['x_axis'] = np.cos(df_business['latitude']) * np.cos(df_business['longitude'])
df_business['y_axis'] = np.cos(df_business['latitude']) * np.sin(df_business['longitude'])

# Dataframe of categories one hot encoded per business_id
df_tmp = df_business['categories'].str.split(pat=', ',expand=True)

# Create dict of categories
for index, row in df_tmp.iterrows():
    for _,elem in row.items():
        if elem and elem not in cat_dict[index]:
            cat_dict[index][elem] += 1

# %%
# Create DF from dict
df_cats = pd.DataFrame.from_dict(cat_dict, orient='index')

#Drop NaN column
df_cats = df_cats.drop(columns='NaN',errors='ignore')

# Fillna with 0
df_cats = df_cats.fillna(0)

# Join back into business
df_business = df_business.join(df_cats,on='business_id')

# Drop cols
df_business = df_business.drop(columns=['address','city','state','postal_code','latitude','longitude','attributes','categories','hours'],errors='ignore')

# Remove elite & friends columns because of non use
df_users = df_users.drop(columns=['elite','friends'],axis=1,errors='ignore')

# %%
display(df_business.head())
# Out:
#                                           name  stars  review_count  is_open  \
# business_id
# M82c96ICluambjx0wWg6Bg           ABZ Auto Care  1.000      0.035500        0
# U_ihDw5JhfmSKBUUkpEQqw              McDonald's  0.375      0.001092        1
# LixFCMGKdptI8WRsjAl5cQ              McDonald's  0.250      0.002185        1
# 064fFc4CdNxAJJDVR-7FSQ  Horton Carpet Cleaning  1.000      0.007646        1
# UY1BHeeb1oE0-uk0EKqaGg              McDonald's  0.125      0.002185        0
#
#                           x_axis    y_axis  Automotive  Auto Repair  \
# business_id
# M82c96ICluambjx0wWg6Bg  0.017129  0.023074         1.0          1.0
# U_ihDw5JhfmSKBUUkpEQqw -0.716416  0.669432         0.0          0.0
# LixFCMGKdptI8WRsjAl5cQ -0.691320  0.697962         0.0          0.0
# 064fFc4CdNxAJJDVR-7FSQ -0.146136 -0.293862         0.0          0.0
# UY1BHeeb1oE0-uk0EKqaGg -0.153528 -0.318958         0.0          0.0
#
#                         Oil Change Stations  Smog Check Stations  ...  \
# business_id                                                       ...
# M82c96ICluambjx0wWg6Bg                  1.0                  1.0  ...
# U_ihDw5JhfmSKBUUkpEQqw                  0.0                  0.0  ...
# LixFCMGKdptI8WRsjAl5cQ                  0.0                  0.0  ...
# 064fFc4CdNxAJJDVR-7FSQ                  0.0                  0.0  ...
# UY1BHeeb1oE0-uk0EKqaGg                  0.0                  0.0  ...
#
#                         Christmas Markets  Kitchen Incubators  \
# business_id
# M82c96ICluambjx0wWg6Bg                0.0                 0.0
# U_ihDw5JhfmSKBUUkpEQqw                0.0                 0.0
# LixFCMGKdptI8WRsjAl5cQ                0.0                 0.0
# 064fFc4CdNxAJJDVR-7FSQ                0.0                 0.0
# UY1BHeeb1oE0-uk0EKqaGg                0.0                 0.0
#
#                         Indoor Landscaping  Marinas  Sailing  Market Stalls  \
# business_id
# M82c96ICluambjx0wWg6Bg                 0.0      0.0      0.0            0.0
# U_ihDw5JhfmSKBUUkpEQqw                 0.0      0.0      0.0            0.0
# LixFCMGKdptI8WRsjAl5cQ                 0.0      0.0      0.0            0.0
# 064fFc4CdNxAJJDVR-7FSQ                 0.0      0.0      0.0            0.0
# UY1BHeeb1oE0-uk0EKqaGg                 0.0      0.0      0.0            0.0
#
#                         Carousels  Tenant and Eviction Law  \
# business_id
# M82c96ICluambjx0wWg6Bg        0.0                      0.0
# U_ihDw5JhfmSKBUUkpEQqw        0.0                      0.0
# LixFCMGKdptI8WRsjAl5cQ        0.0                      0.0
# 064fFc4CdNxAJJDVR-7FSQ        0.0                      0.0
# UY1BHeeb1oE0-uk0EKqaGg        0.0                      0.0
#
#                         Sauna Installation & Repair  Surf Schools
# business_id
# M82c96ICluambjx0wWg6Bg                          0.0           0.0
# U_ihDw5JhfmSKBUUkpEQqw                          0.0           0.0
# LixFCMGKdptI8WRsjAl5cQ                          0.0           0.0
# 064fFc4CdNxAJJDVR-7FSQ                          0.0           0.0
# UY1BHeeb1oE0-uk0EKqaGg                          0.0           0.0
#
# [5 rows x 1153 columns]

# %%
df_business.to_pickle('./business_pickle.pkl')
df_users.to_pickle('./users_pickle.pkl')
df_reviews.to_pickle('./reviews_pickle.pkl')

# %% [markdown]
# ### Basic Data Stats

# %%
# Some information about the category amounts per business

# series of amount of categories per business
cats_business = df_cats.sum(axis=1)
display(cats_business)

avg_cats_bus = cats_business.mean()
max_cats_bus = cats_business.max()
min_cats_bus = cats_business.min()

print('Average amount of categories for businesses: ', avg_cats_bus)
print('Minimum amount of categories for businesses: ', min_cats_bus)
print('Maximum amount of categories for businesses: ', max_cats_bus)

# series of amount of businesses with the index amount of categories
cat_bus_distribution = cats_business.value_counts()
display(cat_bus_distribution)
# Out:
# M82c96ICluambjx0wWg6Bg    4.0
# aNBjTE6FK1XrgssMq-BO4g    9.0
# YCrK4PRlqbwjzBW0lc2FNA    5.0
# uGfpnmFqEscqnNNVn_goaA    3.0
# go9hSfUxG_1REqTi5HZJUw    6.0
#                          ...
# Xm7bTOHKGJ9dIQoq_9b4tw    2.0
# NfUn4rdCLZDFJuznu1qe1Q    2.0
# N9SStuG722_Sg01suvGGsQ    2.0
# u_46RsV4PgRiZrsudUu4Mw    2.0
# _h44VOWq7iKqurDlRu0AlQ    2.0
# Length: 36073, dtype: float64
# Average amount of categories for businesses:  4.082388490006376
# Minimum amount of categories for businesses:  1.0
# Maximum amount of categories for businesses:  21.0
# 2.0     9570
# 3.0     7262
# 4.0     6398
# 5.0     5083
# 6.0     3185
# 7.0     1935
# 8.0     1115
# 9.0      628
# 10.0     301
# 1.0      198
# 11.0     178
# 12.0      92
# 13.0      56
# 14.0      28
# 15.0      20
# 16.0       9
# 17.0       8
# 18.0       4
# 21.0       2
# 20.0       1
# dtype: int64

# %%
# series of number of businesses with index as category
cats_presences = df_cats.sum(axis=0).sort_values(ascending=False)
display(cats_presences)

avg_cats = cats_presences.mean()
max_cats = cats_presences.max()
min_cats = cats_presences.min()
# Out:
# Restaurants             12166.0
# Shopping                 6023.0
# Food                     6014.0
# Beauty & Spas            3658.0
# Home Services            3218.0
#                          ...
# EV Charging Stations        1.0
# Experiences                 1.0
# Apartment Agents            1.0
# Drive-In Theater            1.0
# Surf Schools                1.0
# Length: 1147, dtype: float64

# %% [markdown]
# ### Plots

# %%
hist_bus = df_business.hist(column=['stars','review_count'])
df_business.plot(x='x_axis',y='y_axis',kind='scatter')
plt.show()
cats_presences.plot()
